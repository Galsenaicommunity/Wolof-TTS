# %% [markdown]
# # Fine-tuning Parler-TTS
#
# ## Goal of this notebook
#
# In the following notebook, we'll fine-tune [Parler-TTS Mini v1](https://huggingface.co/parler-tts/parler-tts-mini-v1) on a 5h subset of the [Galsen AI TTS dataset](https://huggingface.co/datasets/galsenai/wolof_tts).
#
# In particular, we'll:
# - Annotate the dataset with natural language speech description using [Data-Speech](https://github.com/huggingface/dataspeech).
# - Fine-tune Parler-TTS with the created dataset.
#
# **You should be able to adapt this notebook to your own datasets quite easily.**

# %% [markdown]
# ## Prepare the Environment
#
# Throughout this tutorial, we'll use a GPU. The runtime is already configured to use the free 16GB T4 GPU provided through Google Colab Free Tier, so all you need to do is hit "Connect T4" in the top right-hand corner of the screen.
#
# ##### <a name="installation"> We'll install Parler-TTS and Data-Speech from source in order to train our model.

# %%
# !git clone https://github.com/huggingface/dataspeech.git
# !cd dataspeech
# !pip install --quiet -r ./dataspeech/requirements.txt
# Out:
# fatal: destination path 'dataspeech' already exists and is not an empty directory.

# %%
# !git clone https://github.com/huggingface/parler-tts.git
# %cd parler-tts
# !pip install --quiet -e .[train]
# Out:
# fatal: destination path 'parler-tts' already exists and is not an empty directory.
# /home/ubuntu/parler-tts
# /home/ubuntu/.local/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-tools 1.66.1 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.19.6 which is incompatible.
# streamlit 1.38.0 requires protobuf<6,>=3.20, but you have protobuf 3.19.6 which is incompatible.
# tensorboardx 2.6.2.2 requires protobuf>=3.20, but you have protobuf 3.19.6 which is incompatible.
# tortoise 3.0.0 requires tokenizers<0.14.0,>=0.13.2, but you have tokenizers 0.19.1 which is incompatible.
# tortoise 3.0.0 requires torchaudio<0.14.0,>=0.13.1, but you have torchaudio 2.5.0 which is incompatible.

# %% [markdown]
# On Colab, we need to run an additional set-up, that you can skip if you're on your local machine.

# %%
# !pip install --upgrade protobuf wandb==0.16.6
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: protobuf in /home/ubuntu/.local/lib/python3.10/site-packages (3.19.6)
# Collecting protobuf
#   Using cached protobuf-5.28.2-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: wandb==0.16.6 in /home/ubuntu/.local/lib/python3.10/site-packages (0.16.6)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from wandb==0.16.6) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from wandb==0.16.6) (3.1.43)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from wandb==0.16.6) (2.32.3)
# Requirement already satisfied: psutil>=5.0.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from wandb==0.16.6) (6.0.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from wandb==0.16.6) (2.13.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from wandb==0.16.6) (0.4.0)
# Requirement already satisfied: PyYAML in /home/ubuntu/.local/lib/python3.10/site-packages (from wandb==0.16.6) (6.0.1)
# Requirement already satisfied: setproctitle in /home/ubuntu/.local/lib/python3.10/site-packages (from wandb==0.16.6) (1.3.3)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from wandb==0.16.6) (59.6.0)
# Requirement already satisfied: appdirs>=1.4.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from wandb==0.16.6) (1.4.4)
#   Using cached protobuf-4.25.5-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: six>=1.4.0 in /usr/lib/python3/dist-packages (from docker-pycreds>=0.4.0->wandb==0.16.6) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb==0.16.6) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ubuntu/.local/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb==0.16.6) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.0.0->wandb==0.16.6) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb==0.16.6) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.0.0->wandb==0.16.6) (2020.6.20)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb==0.16.6) (5.0.1)
# Using cached protobuf-4.25.5-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# descript-audiotools 0.7.2 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.25.5 which is incompatible.
# grpcio-tools 1.66.1 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.5 which is incompatible.
# tortoise 3.0.0 requires tokenizers<0.14.0,>=0.13.2, but you have tokenizers 0.19.1 which is incompatible.
# tortoise 3.0.0 requires torchaudio<0.14.0,>=0.13.1, but you have torchaudio 2.5.0 which is incompatible.
# Successfully installed protobuf-4.25.5

# %% [markdown]
# You should link you Hugging Face account so that you can push model repositories on the Hub. This will allow you to save your trained models on the Hub so that you can share them with the community.
#
# Run the command below and then enter an authentication token from https://huggingface.co/settings/tokens. Create a new token if you do not have one already. You should make sure that this token has "write" privileges.

# %%
# !git config --global credential.helper store
# !huggingface-cli login --token <YOUR_HUGGINGFACE_TOKEN>
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /home/ubuntu/.cache/huggingface/token
# Login successful

# %% [markdown]
# ## 1. Creating our fine-tuning dataset
#
#
# The aim here is to create an annotated version of Anta TTS, in order to fine-tune the [Parler-TTS Mini v1 checkpoint](https://huggingface.co/parler-tts/parler-tts-mini-v1) on this dataset.
#
# Thanks to a [script similar to what's described in the Data-Speech FAQ](https://github.com/huggingface/dataspeech?tab=readme-ov-file#how-do-i-use-datasets-that-i-have-with-this-repository), we've uploaded the dataset to the HuggingFace hub, under the name [galsenai/wolof_tts](https://huggingface.co/datasets/galsenai/wolof_tts).
#
# The purpose of this notebook is demonstration so we'll filter the dataset in order to have only female voice and save it under the name [galsenai/women_wolof_tts](https://huggingface.co/datasets/galsenai/women_wolof_tts).
#
# Feel free to follow the link above to listen to some samples of the TTS dataset thanks to the hub viewer.
#
# We'll:
# 1. Annotate the dataset with continuous variables that measures the speech characteristics
# 2. Map those annotations to text bins that characterize the speech characteristics.
# 3. Create natural language descriptions from those text bins

# %%
# %cd ../dataspeech
# Out:
# /home/ubuntu/dataspeech
# /home/ubuntu/.local/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pip install datasets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: datasets in /home/ubuntu/.local/lib/python3.10/site-packages (2.21.0)
# Requirement already satisfied: filelock in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.32.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.5.0)
# Requirement already satisfied: aiohttp in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (0.23.4)
# Requirement already satisfied: packaging in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ubuntu/.local/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.32.2->datasets) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.32.2->datasets) (2020.6.20)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)

# %%
from datasets import load_dataset
dataset = load_dataset("galsenai/wolof_tts")
# Out:
# Downloading readme:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/395M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/393M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/26684 [00:00<?, ? examples/s]

# %%
def get_women_voice(example):
    return example["gender"] == 'female'

dataset = dataset.filter(get_women_voice)

# %%
def normaliser(example):
    example["transcription_normalised"] = example["text"].lower()
    return example


dataset = dataset.map(get_women_voice)
dataset = dataset.rename_column('text', 'transcription')

dataset.push_to_hub('your_username/women_tts')
# Out:
# Dunu ay buqat.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import Audio
print(dataset["train"][-1]["transcription"])
Audio(dataset["train"][-1]["audio"]["array"], rate=dataset["train"][1]["audio"]["sampling_rate"])
# Out:
# « Jàpp naa ne pólitig du liggéey, j mooy sama liggéey » (Isaa Sàll)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
del dataset

# %% [markdown]
# ### Annotating the dataset
#
# We'll use [`main.py`](https://github.com/huggingface/dataspeech/blob/main/main.py) to get the following continuous variables:
# - Speaking rate `(nb_phonemes / utterance_length)`
# - Scale-Invariant Signal-to-Distortion Ratio (SI-SDR)
# - Reverberation
# - Speech monotony

# %%
# !python3 main.py "your_username/women_tts" \
  --configuration "default" \
  --text_column_name "transcription" \
  --audio_column_name "audio" \
  --cpu_num_workers 2 \
  --rename_column \
  --repo_id "parler_tts" \
  --apply_squim_quality_estimation
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/pyannote/audio/pipelines/speaker_verification.py:43: UserWarning: Module 'speechbrain.pretrained' was deprecated, redirecting to 'speechbrain.inference'. Please update your script. This is a change from SpeechBrain 1.0. See: https://github.com/speechbrain/speechbrain/releases/tag/v1.0.0
#   from speechbrain.pretrained import (
# Compute SI-SDR, PESQ, STOI
# Map:   0%|                                     | 0/26684 [00:00<?, ? examples/s]INFO - The local file (/home/ubuntu/.cache/torch/hub/torchaudio/models/squim_objective_dns2020.pth) exists. Skipping the download.
# Map: 100%|█████████████████████████| 26684/26684 [16:21<00:00, 27.18 examples/s]
# Compute pitch
# Map:   0%|                                     | 0/26684 [00:00<?, ? examples/s]/home/ubuntu/.local/lib/python3.10/site-packages/penn/core.py:421: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint, map_location='cpu')
# Map: 100%|█████████████████████████| 26684/26684 [43:34<00:00, 10.21 examples/s]
# Compute snr and reverb
# Map:   0%|                                     | 0/26684 [00:00<?, ? examples/s]INFO - Lightning automatically upgraded your loaded checkpoint from v1.6.5 to v2.4.0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../.cache/huggingface/hub/models--ylacombe--brouhaha-best/snapshots/99bf97b13fd4dda2434a6f7c50855933076f2937/best.ckpt`
# Model was trained with pyannote.audio 0.0.1, yours is 3.2.0. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.12.1+cu102, yours is 2.5.0+cu124. Bad things might happen unless you revert torch to 1.x.
# Using default parameters optimized on Brouhaha
# /home/ubuntu/.local/lib/python3.10/site-packages/pyannote/audio/core/pipeline.py:317: UserWarning: The pipeline has been automatically instantiated with {'onset': 0.78, 'offset': 0.78, 'min_duration_on': 0, 'min_duration_off': 0}.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/pyannote/audio/utils/reproducibility.py:74: ReproducibilityWarning: TensorFloat-32 (TF32) has been disabled as it might lead to reproducibility issues and lower accuracy.
# It can be re-enabled by calling
#    >>> import torch
#    >>> torch.backends.cuda.matmul.allow_tf32 = True
#    >>> torch.backends.cudnn.allow_tf32 = True
# See https://github.com/pyannote/pyannote-audio/issues/1370 for more details.
#
#   warnings.warn(
# Map:   0%|                           | 2/26684 [00:00<1:54:48,  3.87 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# /home/ubuntu/dataspeech/dataspeech/gpu_enrichments/snr_and_reverb.py:47: RuntimeWarning: Mean of empty slice.
#   snr.append(res["snr"][mask].mean())
# /home/ubuntu/.local/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/ubuntu/dataspeech/dataspeech/gpu_enrichments/snr_and_reverb.py:48: RuntimeWarning: Mean of empty slice.
#   c50.append(res["c50"][mask].mean())
# Map:   0%|                             | 6/26684 [00:00<42:04, 10.57 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                            | 10/26684 [00:00<27:42, 16.04 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                            | 14/26684 [00:00<22:40, 19.60 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                            | 18/26684 [00:01<20:30, 21.68 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                            | 22/26684 [00:01<18:00, 24.68 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                            | 26/26684 [00:01<17:12, 25.83 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                            | 30/26684 [00:01<16:55, 26.24 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                            | 34/26684 [00:01<17:23, 25.54 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                            | 38/26684 [00:01<15:53, 27.93 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                            | 42/26684 [00:01<15:58, 27.80 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                            | 46/26684 [00:02<15:04, 29.46 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                            | 50/26684 [00:02<16:10, 27.45 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                            | 54/26684 [00:02<15:09, 29.28 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                            | 58/26684 [00:02<14:33, 30.48 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                            | 62/26684 [00:02<14:11, 31.27 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                            | 66/26684 [00:02<13:53, 31.93 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                            | 70/26684 [00:02<14:31, 30.52 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                            | 74/26684 [00:02<14:56, 29.69 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                            | 78/26684 [00:03<14:12, 31.20 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                            | 82/26684 [00:03<14:47, 29.98 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                            | 86/26684 [00:03<15:17, 28.98 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                            | 90/26684 [00:03<15:37, 28.36 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                            | 94/26684 [00:03<16:21, 27.08 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                            | 98/26684 [00:03<17:07, 25.89 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                           | 102/26684 [00:03<15:49, 27.99 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                           | 106/26684 [00:04<14:54, 29.72 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                           | 110/26684 [00:04<14:10, 31.23 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                           | 114/26684 [00:04<13:51, 31.94 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                           | 118/26684 [00:04<14:29, 30.57 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|                           | 122/26684 [00:04<14:01, 31.57 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|▏                          | 126/26684 [00:04<13:50, 31.98 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0%|▏                          | 130/26684 [00:04<13:56, 31.75 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 134/26684 [00:04<14:44, 30.02 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 138/26684 [00:05<14:18, 30.91 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 142/26684 [00:05<13:51, 31.91 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 146/26684 [00:05<13:28, 32.82 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 150/26684 [00:05<13:13, 33.44 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 154/26684 [00:05<13:13, 33.42 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 158/26684 [00:05<13:14, 33.37 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 162/26684 [00:05<13:19, 33.19 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 166/26684 [00:05<13:20, 33.14 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 170/26684 [00:06<13:08, 33.65 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 174/26684 [00:06<13:10, 33.54 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 178/26684 [00:06<13:13, 33.41 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 182/26684 [00:06<14:13, 31.06 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 186/26684 [00:06<13:51, 31.87 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 190/26684 [00:06<14:26, 30.56 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 194/26684 [00:06<13:57, 31.63 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 198/26684 [00:06<13:54, 31.73 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 202/26684 [00:07<14:38, 30.15 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 206/26684 [00:07<15:00, 29.39 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 210/26684 [00:07<14:20, 30.77 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 214/26684 [00:07<14:59, 29.42 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 218/26684 [00:07<14:29, 30.45 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 222/26684 [00:07<14:55, 29.54 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 226/26684 [00:07<15:00, 29.38 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 230/26684 [00:08<14:22, 30.69 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 234/26684 [00:08<15:01, 29.34 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 238/26684 [00:08<14:30, 30.39 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 242/26684 [00:08<14:40, 30.02 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▏                          | 246/26684 [00:08<14:56, 29.48 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 250/26684 [00:08<14:20, 30.70 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 254/26684 [00:08<13:55, 31.62 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 258/26684 [00:08<15:26, 28.52 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 262/26684 [00:09<14:36, 30.13 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 266/26684 [00:09<15:46, 27.92 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 270/26684 [00:09<14:48, 29.73 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 274/26684 [00:09<14:11, 31.02 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 278/26684 [00:09<15:49, 27.82 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 282/26684 [00:09<15:43, 27.99 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 286/26684 [00:09<14:49, 29.68 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 290/26684 [00:10<15:53, 27.68 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 294/26684 [00:10<14:56, 29.43 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 298/26684 [00:10<14:15, 30.83 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 302/26684 [00:10<13:51, 31.75 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 306/26684 [00:10<13:39, 32.20 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 310/26684 [00:10<14:18, 30.71 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 314/26684 [00:10<13:45, 31.95 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 318/26684 [00:10<13:25, 32.72 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 322/26684 [00:11<13:57, 31.49 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 326/26684 [00:11<13:40, 32.11 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 330/26684 [00:11<13:20, 32.94 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 334/26684 [00:11<14:06, 31.12 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 338/26684 [00:11<14:38, 30.00 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 342/26684 [00:11<14:00, 31.33 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 346/26684 [00:11<14:40, 29.92 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 350/26684 [00:11<13:56, 31.48 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 354/26684 [00:12<14:25, 30.43 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 358/26684 [00:12<13:51, 31.66 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 362/26684 [00:12<13:35, 32.28 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 366/26684 [00:12<13:27, 32.57 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▎                          | 370/26684 [00:12<13:13, 33.17 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▍                          | 374/26684 [00:12<13:13, 33.17 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▍                          | 378/26684 [00:12<13:02, 33.60 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▍                          | 382/26684 [00:12<13:06, 33.43 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▍                          | 386/26684 [00:13<13:03, 33.56 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▍                          | 390/26684 [00:13<12:53, 33.98 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▍                          | 394/26684 [00:13<13:03, 33.56 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1%|▍                          | 398/26684 [00:13<13:53, 31.55 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 402/26684 [00:13<13:30, 32.44 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 406/26684 [00:13<14:07, 31.02 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 410/26684 [00:13<14:43, 29.73 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 414/26684 [00:13<14:21, 30.50 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 418/26684 [00:14<14:56, 29.30 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 422/26684 [00:14<15:16, 28.66 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 426/26684 [00:14<14:37, 29.91 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 430/26684 [00:14<14:01, 31.20 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 434/26684 [00:14<14:43, 29.72 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 438/26684 [00:14<14:04, 31.09 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 442/26684 [00:14<15:23, 28.43 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 446/26684 [00:15<15:27, 28.28 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 450/26684 [00:15<14:43, 29.68 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 454/26684 [00:15<14:59, 29.15 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 458/26684 [00:15<14:15, 30.67 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 462/26684 [00:15<13:49, 31.63 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 466/26684 [00:15<14:30, 30.10 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 470/26684 [00:15<13:52, 31.50 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 474/26684 [00:15<15:07, 28.90 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 478/26684 [00:16<14:19, 30.50 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 482/26684 [00:16<14:37, 29.85 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 486/26684 [00:16<14:03, 31.05 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 490/26684 [00:16<13:37, 32.04 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▍                          | 494/26684 [00:16<14:02, 31.08 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 498/26684 [00:16<14:36, 29.87 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 502/26684 [00:16<13:57, 31.26 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 506/26684 [00:17<15:06, 28.87 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 510/26684 [00:17<14:23, 30.31 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 514/26684 [00:17<14:48, 29.45 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 518/26684 [00:17<14:15, 30.59 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 522/26684 [00:17<13:52, 31.44 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 526/26684 [00:17<13:28, 32.37 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 530/26684 [00:17<13:13, 32.96 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 534/26684 [00:17<13:50, 31.49 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 538/26684 [00:18<14:21, 30.35 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 542/26684 [00:18<13:52, 31.39 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 546/26684 [00:18<14:24, 30.22 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 550/26684 [00:18<14:50, 29.36 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 554/26684 [00:18<14:20, 30.35 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 558/26684 [00:18<15:27, 28.18 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 562/26684 [00:18<14:46, 29.46 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 566/26684 [00:19<15:03, 28.91 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 570/26684 [00:19<15:07, 28.78 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 574/26684 [00:19<14:21, 30.29 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 578/26684 [00:19<13:43, 31.72 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 582/26684 [00:19<13:27, 32.32 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 586/26684 [00:19<13:17, 32.72 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 590/26684 [00:19<13:10, 33.02 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 594/26684 [00:19<12:57, 33.54 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 598/26684 [00:19<13:40, 31.80 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 602/26684 [00:20<13:36, 31.96 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 606/26684 [00:20<15:09, 28.66 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 610/26684 [00:20<14:19, 30.34 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▌                          | 614/26684 [00:20<13:50, 31.39 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▋                          | 618/26684 [00:20<15:14, 28.50 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▋                          | 622/26684 [00:20<14:23, 30.20 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▋                          | 626/26684 [00:20<13:48, 31.45 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▋                          | 630/26684 [00:21<14:07, 30.75 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▋                          | 634/26684 [00:21<14:28, 30.00 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▋                          | 638/26684 [00:21<14:50, 29.24 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▋                          | 642/26684 [00:21<14:56, 29.05 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▋                          | 646/26684 [00:21<15:16, 28.42 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▋                          | 650/26684 [00:21<14:24, 30.11 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▋                          | 654/26684 [00:21<13:57, 31.09 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▋                          | 658/26684 [00:21<13:39, 31.74 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▋                          | 662/26684 [00:22<14:07, 30.70 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2%|▋                          | 666/26684 [00:22<13:45, 31.53 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▋                          | 670/26684 [00:22<13:20, 32.48 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▋                          | 674/26684 [00:22<14:47, 29.30 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▋                          | 678/26684 [00:22<14:56, 29.00 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▋                          | 682/26684 [00:22<14:22, 30.16 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▋                          | 686/26684 [00:22<13:45, 31.48 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▋                          | 690/26684 [00:23<13:26, 32.24 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▋                          | 694/26684 [00:23<13:09, 32.90 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▋                          | 698/26684 [00:23<13:39, 31.69 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▋                          | 702/26684 [00:23<13:20, 32.44 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▋                          | 706/26684 [00:23<13:05, 33.05 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▋                          | 710/26684 [00:23<12:47, 33.82 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▋                          | 714/26684 [00:23<12:32, 34.49 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▋                          | 718/26684 [00:23<13:22, 32.34 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▋                          | 722/26684 [00:23<13:52, 31.19 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▋                          | 726/26684 [00:24<14:26, 29.97 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▋                          | 730/26684 [00:24<13:57, 31.00 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▋                          | 734/26684 [00:24<13:38, 31.69 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▋                          | 738/26684 [00:24<13:22, 32.32 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 742/26684 [00:24<13:15, 32.62 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 746/26684 [00:24<13:58, 30.95 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 750/26684 [00:24<13:34, 31.83 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 754/26684 [00:24<13:15, 32.59 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 758/26684 [00:25<13:59, 30.87 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 762/26684 [00:25<13:31, 31.96 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 766/26684 [00:25<14:08, 30.55 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 770/26684 [00:25<13:52, 31.13 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 774/26684 [00:25<13:39, 31.61 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 778/26684 [00:25<13:24, 32.18 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 782/26684 [00:25<13:11, 32.73 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 786/26684 [00:26<14:01, 30.76 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 790/26684 [00:26<13:32, 31.86 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 794/26684 [00:26<13:20, 32.33 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 798/26684 [00:26<13:16, 32.51 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 802/26684 [00:26<14:01, 30.75 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 806/26684 [00:26<14:26, 29.85 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 810/26684 [00:26<14:01, 30.76 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 814/26684 [00:26<13:28, 31.98 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 818/26684 [00:27<13:16, 32.46 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 822/26684 [00:27<13:01, 33.11 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 826/26684 [00:27<12:59, 33.17 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 830/26684 [00:27<12:47, 33.67 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 834/26684 [00:27<12:45, 33.77 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 838/26684 [00:27<12:31, 34.39 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 842/26684 [00:27<13:31, 31.85 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 846/26684 [00:27<14:52, 28.96 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 850/26684 [00:28<14:03, 30.64 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 854/26684 [00:28<13:35, 31.66 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 858/26684 [00:28<13:25, 32.05 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▊                          | 862/26684 [00:28<14:11, 30.34 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▉                          | 866/26684 [00:28<13:49, 31.11 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▉                          | 870/26684 [00:28<13:24, 32.09 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▉                          | 874/26684 [00:28<14:02, 30.64 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▉                          | 878/26684 [00:28<14:24, 29.84 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▉                          | 882/26684 [00:29<13:53, 30.94 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▉                          | 886/26684 [00:29<16:10, 26.58 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▉                          | 890/26684 [00:29<15:04, 28.50 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▉                          | 894/26684 [00:29<14:16, 30.10 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▉                          | 898/26684 [00:29<14:34, 29.47 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▉                          | 902/26684 [00:29<14:03, 30.55 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▉                          | 906/26684 [00:29<14:21, 29.92 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▉                          | 910/26684 [00:30<14:04, 30.54 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▉                          | 914/26684 [00:30<14:18, 30.01 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▉                          | 918/26684 [00:30<13:53, 30.90 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▉                          | 922/26684 [00:30<13:31, 31.73 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▉                          | 926/26684 [00:30<13:16, 32.33 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3%|▉                          | 930/26684 [00:30<12:58, 33.09 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4%|▉                          | 934/26684 [00:30<13:34, 31.61 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4%|▉                          | 938/26684 [00:30<14:07, 30.38 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4%|▉                          | 942/26684 [00:31<13:42, 31.31 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4%|▉                          | 946/26684 [00:31<13:23, 32.03 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4%|▉                          | 950/26684 [00:31<13:10, 32.57 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4%|▉                          | 954/26684 [00:31<13:34, 31.60 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4%|▉                          | 958/26684 [00:31<13:09, 32.58 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4%|▉                          | 962/26684 [00:31<13:33, 31.60 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4%|▉                          | 966/26684 [00:31<13:13, 32.43 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4%|▉                          | 970/26684 [00:31<13:38, 31.44 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4%|▉                          | 974/26684 [00:32<13:21, 32.09 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4%|▉                          | 978/26684 [00:32<13:01, 32.90 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4%|▉                          | 982/26684 [00:32<13:37, 31.45 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4%|▉                          | 986/26684 [00:32<13:23, 31.96 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4%|█                          | 990/26684 [00:32<13:52, 30.85 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4%|█                          | 994/26684 [00:32<13:27, 31.81 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4%|█                          | 998/26684 [00:32<14:50, 28.83 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4%|▉                         | 1002/26684 [00:32<14:18, 29.93 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4%|▉                         | 1006/26684 [00:33<13:46, 31.09 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4%|▉                         | 1010/26684 [00:33<14:24, 29.71 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4%|▉                         | 1014/26684 [00:33<13:59, 30.57 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# ...
# Map:  17%|████▌                     | 4666/26684 [02:31<11:41, 31.39 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▌                     | 4670/26684 [02:31<11:20, 32.35 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▌                     | 4674/26684 [02:31<11:13, 32.69 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▌                     | 4678/26684 [02:31<10:56, 33.53 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▌                     | 4682/26684 [02:31<11:38, 31.49 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▌                     | 4686/26684 [02:32<11:17, 32.48 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▌                     | 4690/26684 [02:32<12:35, 29.12 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▌                     | 4694/26684 [02:32<12:01, 30.47 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▌                     | 4698/26684 [02:32<12:13, 29.96 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▌                     | 4702/26684 [02:32<11:40, 31.38 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▌                     | 4706/26684 [02:32<12:52, 28.45 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▌                     | 4710/26684 [02:32<12:09, 30.10 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▌                     | 4714/26684 [02:32<11:43, 31.23 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▌                     | 4718/26684 [02:33<12:36, 29.05 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▌                     | 4722/26684 [02:33<12:06, 30.24 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▌                     | 4726/26684 [02:33<11:33, 31.66 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▌                     | 4730/26684 [02:33<11:12, 32.64 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▌                     | 4734/26684 [02:33<11:51, 30.87 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▌                     | 4738/26684 [02:33<11:24, 32.08 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▌                     | 4742/26684 [02:33<11:39, 31.35 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▌                     | 4746/26684 [02:33<12:00, 30.46 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4750/26684 [02:34<11:32, 31.68 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4754/26684 [02:34<11:18, 32.31 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4758/26684 [02:34<11:51, 30.82 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4762/26684 [02:34<11:32, 31.65 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4766/26684 [02:34<11:20, 32.20 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4770/26684 [02:34<11:05, 32.93 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4774/26684 [02:34<10:57, 33.35 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4778/26684 [02:34<10:48, 33.78 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4782/26684 [02:35<11:34, 31.55 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4786/26684 [02:35<11:17, 32.33 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4790/26684 [02:35<11:02, 33.05 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4794/26684 [02:35<11:45, 31.04 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4798/26684 [02:35<11:24, 31.99 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4802/26684 [02:35<11:43, 31.11 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4806/26684 [02:35<11:23, 31.99 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4810/26684 [02:35<11:08, 32.70 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4814/26684 [02:36<10:55, 33.36 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4818/26684 [02:36<11:36, 31.41 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4822/26684 [02:36<11:25, 31.90 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4826/26684 [02:36<11:16, 32.29 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4830/26684 [02:36<11:18, 32.23 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4834/26684 [02:36<11:46, 30.92 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4838/26684 [02:36<13:05, 27.82 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4842/26684 [02:37<12:21, 29.46 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4846/26684 [02:37<11:57, 30.45 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4850/26684 [02:37<12:11, 29.83 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4854/26684 [02:37<11:39, 31.19 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4858/26684 [02:37<12:05, 30.10 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4862/26684 [02:37<12:36, 28.84 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4866/26684 [02:37<12:43, 28.58 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4870/26684 [02:37<12:05, 30.07 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▋                     | 4874/26684 [02:38<11:38, 31.24 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▊                     | 4878/26684 [02:38<11:16, 32.22 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▊                     | 4882/26684 [02:38<11:07, 32.68 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▊                     | 4886/26684 [02:38<10:53, 33.38 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▊                     | 4890/26684 [02:38<10:54, 33.28 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▊                     | 4894/26684 [02:38<10:42, 33.91 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▊                     | 4898/26684 [02:38<10:33, 34.38 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▊                     | 4902/26684 [02:38<10:32, 34.46 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▊                     | 4906/26684 [02:39<10:32, 34.45 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▊                     | 4910/26684 [02:39<10:33, 34.36 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▊                     | 4914/26684 [02:39<10:33, 34.38 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▊                     | 4918/26684 [02:39<10:29, 34.56 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▊                     | 4922/26684 [02:39<10:28, 34.63 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▊                     | 4926/26684 [02:39<10:31, 34.48 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▊                     | 4930/26684 [02:39<10:32, 34.41 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18%|████▊                     | 4934/26684 [02:39<11:13, 32.29 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▊                     | 4938/26684 [02:39<11:06, 32.63 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▊                     | 4942/26684 [02:40<11:00, 32.90 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▊                     | 4946/26684 [02:40<11:36, 31.23 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▊                     | 4950/26684 [02:40<11:21, 31.87 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▊                     | 4954/26684 [02:40<11:03, 32.77 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▊                     | 4958/26684 [02:40<10:45, 33.66 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▊                     | 4962/26684 [02:40<10:32, 34.36 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▊                     | 4966/26684 [02:40<10:30, 34.43 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▊                     | 4970/26684 [02:40<11:11, 32.34 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▊                     | 4974/26684 [02:41<11:02, 32.77 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▊                     | 4978/26684 [02:41<11:33, 31.28 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▊                     | 4982/26684 [02:41<11:51, 30.50 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▊                     | 4986/26684 [02:41<11:24, 31.72 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▊                     | 4990/26684 [02:41<11:05, 32.60 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▊                     | 4994/26684 [02:41<11:51, 30.50 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▊                     | 4998/26684 [02:41<11:36, 31.14 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▊                     | 5002/26684 [02:41<11:20, 31.86 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▉                     | 5006/26684 [02:42<11:11, 32.27 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▉                     | 5010/26684 [02:42<11:50, 30.52 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▉                     | 5014/26684 [02:42<11:32, 31.31 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▉                     | 5018/26684 [02:42<11:55, 30.28 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▉                     | 5022/26684 [02:42<11:23, 31.71 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▉                     | 5026/26684 [02:42<11:57, 30.19 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19%|████▉                     | 5030/26684 [02:42<12:44, 28.33 examples/s]Using default parameters optimized on Brouhaha

# %% [markdown]
# The whole process took under 10mn!
#
# The resulting dataset will be pushed to the HuggingFace hub under your HuggingFace handle.
#
# Let's see what the new dataset looks like:

# %%
from datasets import load_dataset
dataset = load_dataset("your_username/parler_tts")
print("SI-SDR 1st sample", dataset["train"][0]["si-sdr"])
print("C50 2nd sample", dataset["train"][0]["c50"])
del dataset

# %% [markdown]
# As you can see, the current annotations are continuous variables. To use it with Parler-TTS, we need to convert it to textual description, something that the two next steps will take care of.

# %% [markdown]
# ### 2. Map annotations to text bins
#
# Since the ultimate goal here is to fine-tune the [Parler-TTS v1 Mini checkpoint](https://huggingface.co/parler-tts/parler-tts-mini-v1) on the dataset, we want to stay consistent with the text bins of the datasets on which the latter model was trained.
#
# This is easy to do thanks to the following:

# %%
# !python3 ./scripts/metadata_to_text.py \
    "your_username/parler_tts" \
    --repo_id "parler_tts-text-tags" \
    --configuration "default" \
    --cpu_num_workers 2 \
    --path_to_bin_edges "./examples/tags_to_annotations/v02_bin_edges.json" \
    --path_to_text_bins "./examples/tags_to_annotations/v02_text_bins.json" \
    --avoid_pitch_computation \
    --apply_squim_quality_estimation

# %% [markdown]
# Thanks to [`v02_bin_edges.json`](https://github.com/huggingface/dataspeech/blob/main/examples/tags_to_annotations/v02_bin_edges.json), we don't need to recompute bins from scratch and the above script takes a few seconds.
#
# The resulting dataset will be pushed to the HuggingFace hub under your HuggingFace handle. Mine was push to your_username/parler_tts-text-tags.
#
# You can notice that text bins such as `slightly slowly`, `very monotone` have been added to the samples.

# %%
from datasets import load_dataset
dataset = load_dataset("your_username/parler_tts-text-tags")
print("Noise 1st sample:", dataset["train"][0]["sdr_noise"])
print("Speaking rate 2nd sample:", dataset["train"][0]["speaking_rate"])
del dataset

# %% [markdown]
# ### 3. Create natural language descriptions from those text bins
#
# Now that we have text bins associated to the Anta dataset, the next step is to create natural language descriptions out of the few created features.
#
# Here, we decided to create prompts that use the name `Anta`, prompts that'll look like the following:
# `In a very expressive voice, Anta pronounces her words incredibly slowly. There's some background noise in this room with a bit of echo'`
#
# This step generally demands more resources and times and should use one or many GPUs.
#
# The following command shows how to do it using the [2B version of the Gemma 2 model from Google](https://huggingface.co/google/gemma-2-2b-it), which should run in about 50 minutes in this Colab free T4. Note that we used this model because this notebook aims to show the potential of Parler-TTS fine-tuning, and thus it aims for time-efficiency. Otherwise, we would have gone for a bigger mode.
#
# As usual, we precise the dataset name and configuration we want to annotate. `model_name_or_path` should point to a `transformers` model for prompt annotation. You can find a list of such models [here](https://huggingface.co/models?pipeline_tag=text-generation&library=transformers&sort=trending).
#
# **Note** how we've been able to specify that the dataset is mono-speaker and that we should name the voice Anta thanks to the flags:
#
#
# `--speaker_name "Anta" --is_single_speaker`.

# %%
# !python3 ./scripts/run_prompt_creation.py \
    --speaker_name "Anta" \
    --is_single_speaker \
    --is_new_speaker_prompt \
    --dataset_name "your_username/parler_tts-text-tags" \
    --output_dir "./tmp_anta" \
    --dataset_config_name "default" \
    --model_name_or_path "google/gemma-2-2b-it" \
    --per_device_eval_batch_size 5 \
    --attn_implementation "sdpa" \
    --dataloader_num_workers 2 \
    --push_to_hub \
    --hub_dataset_id "your_username/parler_tts-descriptions-tags" \
    --preprocessing_num_workers 2

# %% [markdown]
# Let's take a look at some created prompts:

# %%
from datasets import load_dataset
dataset = load_dataset("your_username/parler_tts-descriptions-tags")
print("1st sample:", dataset["train"][0]["text_description"])
print("2nd sample:", dataset["train"][1]["text_description"])
del dataset

# %% [markdown]
# ## Fine-tuning Parler-TTS

# %%
# %cd ../parler-tts

# %% [markdown]
# We can know fully focus on fine-tuning Parler-TTS. Luckily, [the Parler-TTS library](https://github.com/huggingface/.parler-tts) has a training script available [here](https://github.com/huggingface/parler-tts/tree/main/training), that can be used with just a few arguments.
#
#
# > **Note:** you need to enter your choice concerning WandB. If you don't have an account, you can enter `3` to avoid logging on WandB. Otherwise; you can logging to follow how your model trained.

# %%
# !accelerate launch ./training/run_parler_tts_training.py \
    --model_name_or_path "parler-tts/parler-tts-mini-v1" \
    --feature_extractor_name "parler-tts/dac_44khZ_8kbps" \
    --description_tokenizer_name "parler-tts/parler-tts-mini-v1" \
    --prompt_tokenizer_name "parler-tts/parler-tts-mini-v1" \
    --report_to "wandb" \
    --overwrite_output_dir true \
    --train_dataset_name "your_username/women_tts" \
    --train_metadata_dataset_name "your_username/parler_tts-descriptions-tags" \
    --train_dataset_config_name "default" \
    --train_split_name "train" \
    --eval_dataset_name "your_username/women_tts" \
    --eval_metadata_dataset_name "your_username/parler_tts-descriptions-tags" \
    --eval_dataset_config_name "default" \
    --eval_split_name "train" \
    --max_eval_samples 8 \
    --per_device_eval_batch_size 8 \
    --target_audio_column_name "audio" \
    --description_column_name "text_description" \
    --prompt_column_name "text" \
    --max_duration_in_seconds 20 \
    --min_duration_in_seconds 2.0 \
    --max_text_length 400 \
    --preprocessing_num_workers 2 \
    --do_train true \
    --num_train_epochs 2 \
    --gradient_accumulation_steps 18 \
    --gradient_checkpointing true \
    --per_device_train_batch_size 2 \
    --learning_rate 0.0001 \
    --adam_beta1 0.9 \
    --adam_beta2 0.99 \
    --weight_decay 0.01 \
    --lr_scheduler_type "constant_with_warmup" \
    --warmup_steps 50 \
    --logging_steps 2 \
    --freeze_text_encoder true \
    --audio_encoder_per_device_batch_size 5 \
    --dtype "float16" \
    --seed 456 \
    --output_dir "./output_dir_training/" \
    --temporary_save_to_disk "./audio_code_tmp/" \
    --save_to_disk "./tmp_dataset_audio/" \
    --dataloader_num_workers 2 \
    --do_eval \
    --predict_with_generate \
    --include_inputs_for_metrics \
    --group_by_length true

# %% [markdown]
# ## Inference
#
# The full training on the free T4 from Google Colab took about an hour.
# Now, let's see how to do inference with the newly fine-tuned model!

# %% [markdown]
# First install the Parler-TTS library:

# %%
# !pip install git+https://github.com/huggingface/parler-tts.git

# %% [markdown]
# Then:

# %%
from parler_tts import ParlerTTSForConditionalGeneration
from transformers import AutoTokenizer
import torch

device = "cuda:0" if torch.cuda.is_available() else "cpu"

model = ParlerTTSForConditionalGeneration.from_pretrained("/content/parler-tts/output_dir_training", torch_dtype=torch.float16).to(device)
tokenizer = AutoTokenizer.from_pretrained("parler-tts/parler_tts_mini_v0.1")

prompt = "Hey, how are you doing today?"
description = "'Anta delivers her words quite expressively, in a very confined sounding environment with clear audio quality. She speaks fast.'"

input_ids = tokenizer(description, return_tensors="pt").input_ids.to(device)
prompt_input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(device)

generation = model.generate(input_ids=input_ids, prompt_input_ids=prompt_input_ids)
audio_arr = generation.cpu().numpy().squeeze()

# %% [markdown]
# This is great! As you can see, the model now managed to get a **consistent** voice throughout generation that looks like **Anta**!
#
# Since we're quite happy about it, let's push it to the hub to be able to re-use it!

# %%
model.push_to_hub("parler-tts-mini-v1-wolof-colab")
tokenizer.push_to_hub("parler-tts-mini-v1-wolof-colab")

# %% [markdown]
# You'll now be able to load the model and the tokenizer using the direct repository id of your model, i.e `<your_HF_handle>/parler-tts-mini-wolof-colab`.
#
# ```python
# model = ParlerTTSForConditionalGeneration.from_pretrained("<your_HF_handle>/parler-tts-mini-wolof-colab").to(device)
# tokenizer = AutoTokenizer.from_pretrained("<your_HF_handle>/parler-tts-mini-wolof-colab")
# ```

# %% [markdown]
# ## Conclusion
#
# To conclude, we've shown here how to fine-tune Parler-TTS Mini v1 on this newly created dataset!
#
# **If you want to fine-tune the model on your own dataset, you can follow and/or adapt the current notebook to make it work!
